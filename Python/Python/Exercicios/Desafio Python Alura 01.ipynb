# %%
print("Olá Mundo")
print("Meu primeiro programa")
print("Hello Word")
# Out:
# Olá Mundo
# Meu primeiro programa
# Hello Word

# %%
nome = input("Informe o Nome: ")
sobrenome = input("Informe o Sobrenome: ")
ano_curso = int(input("Informe o Ano do Curso: "))

print(f"Meu nome é {nome} {sobrenome} é estou fazendo o curso da Alura em {ano_curso}")
# Out:
# Informe o Nome: João
# Informe o Sobrenome: Vitor
# Informe o Ano do Curso: 2025
# Meu nome é João Vitor é estou fazendo o curso da Alura em 2025
